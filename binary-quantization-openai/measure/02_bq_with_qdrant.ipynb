# %% [markdown]
# # OpenAI x Qdrant
#
# ## Binary Quantization with OpenAI Ada-003 Embeddings
#
# This notebook demonstrates how to use Qdrant to index and search OpenAI Ada-003 embeddings. We will compare the production-like search performance of Qdrant with Binary Quantization with the brute-force search. We will use [Qdrant Cloud](https://qdrant.to/cloud?utm_source=qdrant&utm_medium=social&utm_campaign=binary-openai-v3&utm_content=article) to index and search the embeddings.

# %%
import json
import os

import loguru
import numpy as np
import random
from datasets import load_dataset
from datasets.exceptions import DatasetNotFoundError
from dotenv import load_dotenv
from qdrant_client import QdrantClient, models
from qdrant_client.models import PointStruct
from tqdm import tqdm

load_dotenv()  # take environment variables from .env
logger = loguru.logger
logger.add("logs.log", format="{time} {level} {message}", level="INFO")

# %% [markdown]
# # Setup a Qdrant Client connection
#
# We will use the `qdrant-client` python package to interact with Qdrant. You can install it with `pip install qdrant-client`. We manage our dependencies using Poetry, so you can install all the dependencies with `poetry install`.

# %%
client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY"),
    timeout=100,
)

# %%
bs = 512

# %%
dataset_combinations = [
    # {
    #     "model_name": "text-embedding-3-large",
    #     "dimensions": 3072,
    # },
    # {
    #     "model_name": "text-embedding-3-large",
    #     "dimensions": 1024,
    # },
    # {
    #     "model_name": "text-embedding-3-large",
    #     "dimensions": 1536,
    # },
    {
        "model_name": "text-embedding-3-small",
        "dimensions": 512,
    },
    # {
    #     "model_name": "text-embedding-3-small",
    #     "dimensions": 1024,
    # },
    # {
    #     "model_name": "text-embedding-3-small",
    #     "dimensions": 1536,
    # },
]

# %%
for combination in dataset_combinations:
    MODEL_NAME, DIMENSIONS = combination["model_name"], combination["dimensions"]
    DATASET_NAME = f"Qdrant/dbpedia-entities-openai3-{MODEL_NAME}-{DIMENSIONS}-100K"
    collection_name = f"dbpedia-{MODEL_NAME}-{DIMENSIONS}"
    embedding_column_name = f"{MODEL_NAME}-{DIMENSIONS}-embedding"
    try:
        client.recreate_collection(
            collection_name=collection_name,
            vectors_config=models.VectorParams(
                size=DIMENSIONS,
                distance=models.Distance.COSINE,
            ),
            optimizers_config=models.OptimizersConfigDiff(
                indexing_threshold=0,
                # Turn off indexing for faster upserts
            ),
            quantization_config=models.BinaryQuantization(
                binary=models.BinaryQuantizationConfig(always_ram=True),
            ),
            shard_number=2,
        )
    except Exception as e:
        collection_info = client.get_collection(collection_name=collection_name)
        logger.error(f"Collection {collection_name} already exists with {collection_info.points_count} points. {e}")
        continue
    logger.info(f"Created collection {collection_name}")
    try:
        dataset = load_dataset(
        DATASET_NAME,
        streaming=False,
        split="train",
    )
    except DatasetNotFoundError:
        logger.error(f"Dataset {DATASET_NAME} not found")
        continue
    logger.info(f"Loaded {DATASET_NAME} dataset")
    points = [
        {
            "id": i,
            "vector": embedding,
            "payload": {"text": data["text"], "title": data["title"]},
        }
        for i, (embedding, data) in enumerate(zip(dataset[embedding_column_name], dataset))
    ]
    points = [PointStruct(**point) for point in points]
    logger.info(f"Loaded {len(points)} points")
    
    collection_info = client.get_collection(collection_name=collection_name)
    if collection_info.vectors_count == 0:
        logger.info("Collection is empty. Begin upsert.")
        for i in tqdm(range(0, len(points), bs)):
            slice_points = points[i : i + bs]  # Create a slice of bs points
            client.upsert(
                collection_name=collection_name, points=slice_points, wait=True
            )
    # After the upsert, we can turn on indexing for faster search
    client.update_collection(
        collection_name=f"{collection_name}",
        optimizer_config=models.OptimizersConfigDiff(indexing_threshold=20000),
    )
    logger.info(f"Collection {collection_name} is ready")
# Out:
# 2024-02-06 12:17:09.274 | INFO     | __main__:<module>:26 - Created collection dbpedia-text-embedding-3-small-512
# 2024-02-06 12:17:15.988 | INFO     | __main__:<module>:36 - Loaded Qdrant/dbpedia-entities-openai3-text-embedding-3-small-512-100K dataset
# 2024-02-06 12:17:35.932 | INFO     | __main__:<module>:46 - Loaded 100000 points
# 2024-02-06 12:17:36.688 | INFO     | __main__:<module>:50 - Collection is empty. Begin upsert.
# 100%|██████████| 196/196 [03:19<00:00,  1.02s/it]
# 2024-02-06 12:20:56.677 | INFO     | __main__:<module>:61 - Collection dbpedia-text-embedding-3-small-512 is ready

# %% [markdown]
# > 💡 Note on Indexing: Since Indexing is a background process, it does not affect our exact search performance. Turning off the indexing allows for faster uploads and writes.

# %% [markdown]
# ## Create a valuation split for the BQ to Compare exact with approximate

# %%
oversampling_range = np.arange(1.0, 3.1, 1.0)
rescore_range = [True, False]

# %% [markdown]
# # Parameterized Search
#
# We will use the `qdrant-client` to perform a parameterized search. We will compare the exact search performance with the approximate search performance. We will use the `search` method to perform the exact search with exact=True.

# %%
def parameterized_search(
    point,
    oversampling: float,
    rescore: bool,
    exact: bool,
    collection_name: str,
    ignore: bool = False,
    limit: int = 10,
):
    if exact:
        return client.search(
            collection_name=collection_name,
            query_vector=point.vector,
            search_params=models.SearchParams(exact=exact),
            limit=limit,
        )
    else:
        return client.search(
            collection_name=collection_name,
            query_vector=point.vector,
            search_params=models.SearchParams(
                quantization=models.QuantizationSearchParams(
                    ignore=ignore,
                    rescore=rescore,
                    oversampling=oversampling,
                ),
                exact=exact,
            ),
            limit=limit,
        )

# %%
for combination in dataset_combinations:
    MODEL_NAME, DIMENSIONS = combination["model_name"], combination["dimensions"]
    DATASET_NAME = f"Qdrant/dbpedia-entities-openai3-{MODEL_NAME}-{DIMENSIONS}-100K"
    collection_name = f"dbpedia-{MODEL_NAME}-{DIMENSIONS}"
    embedding_column_name = f"{MODEL_NAME}-{DIMENSIONS}-embedding"
    dataset = load_dataset(
        DATASET_NAME,
        streaming=False,
        split="train",
    )
    ds = dataset.train_test_split(test_size=0.001, shuffle=True, seed=37)["test"]
    ds = ds.to_pandas().to_dict(orient="records")
    logger.info(f"Loaded {DATASET_NAME} dataset")
    results = []
    with open(f"results-{MODEL_NAME}-{DIMENSIONS}.json", "w+") as f:
        for element in tqdm(ds):
            # print(element.payload["text"])
            # print("Oversampling")
            point = PointStruct(
                id=random.randint(0, 100000),
                vector=element[embedding_column_name],
            )
            ## Running Grid Search
            for oversampling in oversampling_range:
                for rescore in rescore_range:
                    limit_range = [100, 50, 20, 10, 5]
                    for limit in limit_range:
                        try:
                            exact = parameterized_search(
                                point=point,
                                oversampling=oversampling,
                                rescore=rescore,
                                exact=True,
                                collection_name=collection_name,
                                limit=limit,
                            )
                            hnsw = parameterized_search(
                                point=point,
                                oversampling=oversampling,
                                rescore=rescore,
                                exact=False,
                                collection_name=collection_name,
                                limit=limit,
                            )
                        except Exception as e:
                            print(f"Skipping point: {point}\n{e}")
                            continue

                        exact_ids = [item.id for item in exact]
                        hnsw_ids = [item.id for item in hnsw]
                        # logger.info(f"Exact: {exact_ids}")
                        # logger.info(f"HNSW: {hnsw_ids}")

                        accuracy = len(set(exact_ids) & set(hnsw_ids)) / len(exact_ids)

                        if accuracy is None:
                            continue

                        result = {
                            "query_id": point.id,
                            "oversampling": oversampling,
                            "rescore": rescore,
                            "limit": limit,
                            "accuracy": accuracy,
                        }
                        f.write(json.dumps(result))
                        f.write("\n")
                        logger.info(result)
# Out:
# 2024-02-06 12:43:39.742 | INFO     | __main__:<module>:13 - Loaded Qdrant/dbpedia-entities-openai3-text-embedding-3-small-512-100K dataset
#   0%|          | 0/100 [00:00<?, ?it/s]2024-02-06 12:43:41.275 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.44}
# 2024-02-06 12:43:41.805 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 12:43:42.331 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 12:43:42.858 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.3}
# 2024-02-06 12:43:43.381 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:43:43.908 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.31}
# 2024-02-06 12:43:44.435 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.38}
# 2024-02-06 12:43:44.959 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.25}
# 2024-02-06 12:43:45.482 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.2}
# 2024-02-06 12:43:46.008 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:43:46.590 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.67}
# 2024-02-06 12:43:47.142 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.56}
# 2024-02-06 12:43:47.673 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:43:48.268 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:43:48.822 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 12:43:49.362 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.35}
# 2024-02-06 12:43:49.894 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.38}
# 2024-02-06 12:43:50.421 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.25}
# 2024-02-06 12:43:50.945 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.2}
# 2024-02-06 12:43:51.473 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:43:52.002 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.74}
# 2024-02-06 12:43:52.526 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.7}
# 2024-02-06 12:43:53.053 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:43:53.583 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:43:54.112 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:43:54.645 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.35}
# 2024-02-06 12:43:55.177 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.4}
# 2024-02-06 12:43:55.703 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.25}
# 2024-02-06 12:43:56.233 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.2}
# 2024-02-06 12:43:56.769 | INFO     | __main__:<module>:68 - {'query_id': 88849, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
#   1%|          | 1/100 [00:17<28:05, 17.03s/it]2024-02-06 12:43:57.307 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.61}
# 2024-02-06 12:43:57.832 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.6}
# 2024-02-06 12:43:58.369 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.8}
# 2024-02-06 12:43:58.900 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 1.0}
# 2024-02-06 12:43:59.427 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:43:59.961 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.47}
# 2024-02-06 12:44:00.495 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.48}
# 2024-02-06 12:44:01.045 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 12:44:01.579 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:44:02.108 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:02.725 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.74}
# 2024-02-06 12:44:03.257 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.78}
# 2024-02-06 12:44:03.784 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:04.310 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 1.0}
# 2024-02-06 12:44:04.838 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:05.374 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.46}
# 2024-02-06 12:44:05.902 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.48}
# 2024-02-06 12:44:06.433 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 12:44:06.963 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:44:07.491 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:08.026 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.85}
# 2024-02-06 12:44:08.557 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.84}
# 2024-02-06 12:44:09.087 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:09.614 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 1.0}
# 2024-02-06 12:44:10.142 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:10.677 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.46}
# 2024-02-06 12:44:11.213 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.48}
# 2024-02-06 12:44:11.757 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 12:44:12.415 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:44:12.946 | INFO     | __main__:<module>:68 - {'query_id': 78589, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#   2%|▏         | 2/100 [00:33<26:59, 16.53s/it]2024-02-06 12:44:13.492 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.68}
# 2024-02-06 12:44:14.077 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.62}
# 2024-02-06 12:44:14.605 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:44:15.139 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:44:15.667 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:16.211 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.49}
# 2024-02-06 12:44:16.744 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 12:44:17.276 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.3}
# 2024-02-06 12:44:17.809 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 12:44:18.337 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:18.877 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.8}
# 2024-02-06 12:44:19.408 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.82}
# 2024-02-06 12:44:20.025 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:20.554 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:44:21.082 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:21.949 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.48}
# 2024-02-06 12:44:22.478 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 12:44:23.002 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.3}
# 2024-02-06 12:44:23.532 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 12:44:24.063 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:24.600 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.87}
# 2024-02-06 12:44:25.131 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.88}
# 2024-02-06 12:44:25.662 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.9}
# 2024-02-06 12:44:26.196 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 1.0}
# 2024-02-06 12:44:26.728 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:27.269 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.48}
# 2024-02-06 12:44:27.889 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.42}
# 2024-02-06 12:44:28.462 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.3}
# 2024-02-06 12:44:28.986 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 12:44:29.587 | INFO     | __main__:<module>:68 - {'query_id': 69464, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#   3%|▎         | 3/100 [00:49<26:48, 16.58s/it]2024-02-06 12:44:30.131 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.55}
# 2024-02-06 12:44:30.665 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.56}
# 2024-02-06 12:44:31.292 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:44:31.892 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:44:32.423 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:32.963 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.41}
# 2024-02-06 12:44:33.498 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 12:44:34.035 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.55}
# 2024-02-06 12:44:34.566 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:44:35.096 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:35.632 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.71}
# 2024-02-06 12:44:36.163 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.66}
# 2024-02-06 12:44:36.695 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:37.421 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:44:37.952 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:38.552 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.41}
# 2024-02-06 12:44:39.224 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 12:44:39.765 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.55}
# 2024-02-06 12:44:40.296 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:44:40.820 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:41.364 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.83}
# 2024-02-06 12:44:41.896 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.72}
# 2024-02-06 12:44:42.426 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:42.952 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:44:43.476 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:44:44.008 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.42}
# 2024-02-06 12:44:44.543 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.4}
# 2024-02-06 12:44:45.072 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.55}
# 2024-02-06 12:44:45.599 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:44:46.121 | INFO     | __main__:<module>:68 - {'query_id': 20864, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
#   4%|▍         | 4/100 [01:06<26:29, 16.56s/it]2024-02-06 12:44:46.668 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.64}
# 2024-02-06 12:44:47.291 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.72}
# 2024-02-06 12:44:47.838 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:44:48.370 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:44:48.896 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:49.431 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.5}
# 2024-02-06 12:44:49.961 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.52}
# 2024-02-06 12:44:50.496 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:44:51.025 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:44:51.552 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:52.085 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.81}
# 2024-02-06 12:44:52.623 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.8}
# 2024-02-06 12:44:53.154 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.75}
# 2024-02-06 12:44:53.682 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:44:54.349 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:44:54.888 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.52}
# 2024-02-06 12:44:55.421 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.52}
# 2024-02-06 12:44:55.958 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:44:56.486 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:44:57.017 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:44:57.555 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.86}
# 2024-02-06 12:44:58.084 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.84}
# 2024-02-06 12:44:58.611 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:44:59.141 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:44:59.669 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:45:00.202 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.53}
# 2024-02-06 12:45:00.733 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.52}
# 2024-02-06 12:45:01.272 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:45:01.797 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:02.324 | INFO     | __main__:<module>:68 - {'query_id': 80188, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#   5%|▌         | 5/100 [01:22<26:01, 16.43s/it]2024-02-06 12:45:02.868 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.74}
# 2024-02-06 12:45:03.402 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.64}
# 2024-02-06 12:45:03.933 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:04.468 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:05.002 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:45:05.547 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.55}
# 2024-02-06 12:45:06.165 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.48}
# 2024-02-06 12:45:06.695 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:45:07.231 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:07.764 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 12:45:08.307 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.92}
# 2024-02-06 12:45:08.839 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.84}
# 2024-02-06 12:45:09.374 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 12:45:09.905 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:10.437 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:10.970 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.55}
# 2024-02-06 12:45:11.509 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.48}
# 2024-02-06 12:45:12.040 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:45:12.572 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:13.098 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 12:45:13.634 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.93}
# 2024-02-06 12:45:14.168 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.9}
# 2024-02-06 12:45:14.700 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.8}
# 2024-02-06 12:45:15.228 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:15.756 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:16.388 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.54}
# 2024-02-06 12:45:16.925 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.46}
# 2024-02-06 12:45:17.461 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:45:17.995 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:18.534 | INFO     | __main__:<module>:68 - {'query_id': 93385, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
#   6%|▌         | 6/100 [01:38<25:37, 16.36s/it]2024-02-06 12:45:19.075 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.61}
# 2024-02-06 12:45:19.612 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.58}
# 2024-02-06 12:45:20.146 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:45:20.676 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:21.203 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:45:21.747 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.47}
# 2024-02-06 12:45:22.279 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.42}
# 2024-02-06 12:45:22.809 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:45:23.462 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:45:23.992 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:45:24.527 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.79}
# 2024-02-06 12:45:25.074 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.66}
# 2024-02-06 12:45:25.754 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:26.285 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:26.816 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:27.351 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.46}
# 2024-02-06 12:45:27.884 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.42}
# 2024-02-06 12:45:28.414 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:45:28.946 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:45:29.470 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:45:30.006 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.88}
# 2024-02-06 12:45:30.539 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.82}
# 2024-02-06 12:45:31.071 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 12:45:31.598 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:32.124 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:32.661 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.46}
# 2024-02-06 12:45:33.189 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.42}
# 2024-02-06 12:45:33.713 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:45:34.240 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:45:34.778 | INFO     | __main__:<module>:68 - {'query_id': 42222, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#   7%|▋         | 7/100 [01:55<25:17, 16.32s/it]2024-02-06 12:45:35.319 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.81}
# 2024-02-06 12:45:35.996 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.82}
# 2024-02-06 12:45:36.530 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.9}
# 2024-02-06 12:45:37.061 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:37.587 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:38.131 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.65}
# 2024-02-06 12:45:38.669 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.66}
# 2024-02-06 12:45:39.198 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:39.723 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:40.251 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:45:40.788 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.96}
# 2024-02-06 12:45:41.322 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.9}
# 2024-02-06 12:45:41.846 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.95}
# 2024-02-06 12:45:42.397 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:42.958 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:43.633 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.65}
# 2024-02-06 12:45:44.163 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.66}
# 2024-02-06 12:45:44.693 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:45.221 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:45.748 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:45:46.283 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.97}
# 2024-02-06 12:45:46.821 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.94}
# 2024-02-06 12:45:47.352 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.95}
# 2024-02-06 12:45:47.880 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:45:48.408 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:45:48.962 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.64}
# 2024-02-06 12:45:49.494 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.66}
# 2024-02-06 12:45:50.029 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:50.728 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:45:51.266 | INFO     | __main__:<module>:68 - {'query_id': 55877, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
#   8%|▊         | 8/100 [02:11<25:06, 16.37s/it]2024-02-06 12:45:51.813 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.63}
# 2024-02-06 12:45:52.342 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.62}
# 2024-02-06 12:45:52.871 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 12:45:53.607 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:45:54.220 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:45:54.755 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.46}
# 2024-02-06 12:45:55.379 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.5}
# 2024-02-06 12:45:55.909 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:45:56.443 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:45:56.977 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:45:57.524 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.83}
# 2024-02-06 12:45:58.062 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.8}
# 2024-02-06 12:45:58.591 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:45:59.116 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:45:59.640 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:46:00.177 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.44}
# 2024-02-06 12:46:00.715 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.5}
# 2024-02-06 12:46:01.240 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:46:01.769 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:46:02.292 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:46:02.818 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.87}
# 2024-02-06 12:46:03.349 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.9}
# 2024-02-06 12:46:03.880 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.8}
# 2024-02-06 12:46:04.409 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 12:46:04.935 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:46:05.474 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.43}
# 2024-02-06 12:46:06.112 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.5}
# 2024-02-06 12:46:06.714 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 12:46:07.243 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:46:07.770 | INFO     | __main__:<module>:68 - {'query_id': 21706, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#   9%|▉         | 9/100 [02:28<24:53, 16.41s/it]2024-02-06 12:46:08.314 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.57}
# 2024-02-06 12:46:08.843 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.58}
# 2024-02-06 12:46:09.373 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:46:09.900 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.3}
# 2024-02-06 12:46:10.450 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:46:10.998 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.4}
# 2024-02-06 12:46:11.628 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.38}
# 2024-02-06 12:46:12.179 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 12:46:12.708 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.1}
# 2024-02-06 12:46:13.232 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:46:13.769 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.78}
# 2024-02-06 12:46:14.305 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.72}
# 2024-02-06 12:46:14.834 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.75}
# 2024-02-06 12:46:15.367 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 12:46:15.893 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 12:46:16.440 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.43}
# 2024-02-06 12:46:16.977 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.38}
# 2024-02-06 12:46:17.506 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 12:46:18.081 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.1}
# 2024-02-06 12:46:18.791 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
# 2024-02-06 12:46:19.326 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.86}
# 2024-02-06 12:46:19.859 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.78}
# 2024-02-06 12:46:20.387 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 12:46:20.909 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 12:46:21.430 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 12:46:21.968 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.42}
# 2024-02-06 12:46:22.648 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.42}
# 2024-02-06 12:46:23.173 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 12:46:23.704 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.1}
# 2024-02-06 12:46:24.231 | INFO     | __main__:<module>:68 - {'query_id': 77416, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.2}
#  10%|█         | 10/100 [02:44<24:38, 16.43s/it]2024-02-06 12:46:24.773 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.71}
# 2024-02-06 12:46:25.312 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.7}
# 2024-02-06 12:46:25.845 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 12:46:26.384 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 12:46:26.917 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 12:46:27.453 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.5}
# 2024-02-06 12:46:27.984 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.52}
# 2024-02-06 12:46:28.516 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.45}
# 2024-02-06 12:46:29.043 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.3}
# 2024-02-06 12:46:29.571 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 12:46:30.107 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.93}
# 2024-02-06 12:46:30.699 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.9}
# 2024-02-06 12:46:31.301 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.8}
# 2024-02-06 12:46:31.834 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 12:46:32.360 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 12:46:32.896 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.48}
# 2024-02-06 12:46:33.423 | INFO     | __main__:<module>:68 - {'query_id': 46134, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.52}
# ...
# 2024-02-06 13:09:42.313 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:09:42.847 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.54}
# 2024-02-06 13:09:43.377 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.58}
# 2024-02-06 13:09:43.905 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 13:09:44.436 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:09:44.971 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 13:09:45.506 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.87}
# 2024-02-06 13:09:46.044 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.92}
# 2024-02-06 13:09:46.573 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.95}
# 2024-02-06 13:09:47.104 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 13:09:47.631 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:09:48.264 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.55}
# 2024-02-06 13:09:48.800 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.56}
# 2024-02-06 13:09:49.327 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 13:09:49.850 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:09:50.373 | INFO     | __main__:<module>:68 - {'query_id': 35301, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
#  97%|█████████▋| 97/100 [26:10<00:48, 16.14s/it]2024-02-06 13:09:50.907 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.58}
# 2024-02-06 13:09:51.433 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.56}
# 2024-02-06 13:09:51.957 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.4}
# 2024-02-06 13:09:52.486 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 13:09:53.011 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 13:09:53.544 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.4}
# 2024-02-06 13:09:54.076 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 13:09:54.605 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 13:09:55.134 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 13:09:55.659 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 13:09:56.194 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.72}
# 2024-02-06 13:09:56.773 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.76}
# 2024-02-06 13:09:57.305 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.55}
# 2024-02-06 13:09:57.829 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 13:09:58.371 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:09:58.904 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.4}
# 2024-02-06 13:09:59.429 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 13:10:00.043 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 13:10:00.573 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 13:10:01.101 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
# 2024-02-06 13:10:01.630 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.81}
# 2024-02-06 13:10:02.155 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.84}
# 2024-02-06 13:10:02.684 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.65}
# 2024-02-06 13:10:03.219 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.7}
# 2024-02-06 13:10:03.743 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:04.277 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.4}
# 2024-02-06 13:10:04.808 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.44}
# 2024-02-06 13:10:05.337 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.35}
# 2024-02-06 13:10:05.874 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.4}
# 2024-02-06 13:10:06.409 | INFO     | __main__:<module>:68 - {'query_id': 88573, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.4}
#  98%|█████████▊| 98/100 [26:26<00:32, 16.11s/it]2024-02-06 13:10:06.946 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.79}
# 2024-02-06 13:10:07.485 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.82}
# 2024-02-06 13:10:08.017 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 13:10:08.546 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 13:10:09.075 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:09.631 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.65}
# 2024-02-06 13:10:10.163 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.64}
# 2024-02-06 13:10:10.691 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 13:10:11.217 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:11.748 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:12.283 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.89}
# 2024-02-06 13:10:12.902 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.98}
# 2024-02-06 13:10:13.432 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.85}
# 2024-02-06 13:10:13.958 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 13:10:14.482 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:15.012 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.65}
# 2024-02-06 13:10:15.544 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.64}
# 2024-02-06 13:10:16.072 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 13:10:16.598 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:17.128 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:17.660 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.96}
# 2024-02-06 13:10:18.190 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 1.0}
# 2024-02-06 13:10:18.721 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 1.0}
# 2024-02-06 13:10:19.250 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 13:10:19.777 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 13:10:20.314 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.64}
# 2024-02-06 13:10:20.844 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.62}
# 2024-02-06 13:10:21.373 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.5}
# 2024-02-06 13:10:21.900 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:22.425 | INFO     | __main__:<module>:68 - {'query_id': 47915, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.8}
#  99%|█████████▉| 99/100 [26:42<00:16, 16.08s/it]2024-02-06 13:10:22.970 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': True, 'limit': 100, 'accuracy': 0.71}
# 2024-02-06 13:10:23.505 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': True, 'limit': 50, 'accuracy': 0.76}
# 2024-02-06 13:10:24.028 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': True, 'limit': 20, 'accuracy': 0.7}
# 2024-02-06 13:10:24.553 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': True, 'limit': 10, 'accuracy': 0.6}
# 2024-02-06 13:10:25.077 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:25.614 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': False, 'limit': 100, 'accuracy': 0.54}
# 2024-02-06 13:10:26.139 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': False, 'limit': 50, 'accuracy': 0.54}
# 2024-02-06 13:10:26.670 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 13:10:27.196 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:27.897 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 1.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 13:10:28.430 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': True, 'limit': 100, 'accuracy': 0.91}
# 2024-02-06 13:10:28.956 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': True, 'limit': 50, 'accuracy': 0.92}
# 2024-02-06 13:10:29.485 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': True, 'limit': 20, 'accuracy': 0.9}
# 2024-02-06 13:10:30.011 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': True, 'limit': 10, 'accuracy': 0.8}
# 2024-02-06 13:10:30.537 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': True, 'limit': 5, 'accuracy': 0.8}
# 2024-02-06 13:10:31.079 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': False, 'limit': 100, 'accuracy': 0.55}
# 2024-02-06 13:10:31.615 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': False, 'limit': 50, 'accuracy': 0.54}
# 2024-02-06 13:10:32.144 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 13:10:32.670 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:33.193 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 2.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 2024-02-06 13:10:33.732 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': True, 'limit': 100, 'accuracy': 0.94}
# 2024-02-06 13:10:34.264 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': True, 'limit': 50, 'accuracy': 0.96}
# 2024-02-06 13:10:34.792 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': True, 'limit': 20, 'accuracy': 0.9}
# 2024-02-06 13:10:35.320 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': True, 'limit': 10, 'accuracy': 0.9}
# 2024-02-06 13:10:35.853 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': True, 'limit': 5, 'accuracy': 1.0}
# 2024-02-06 13:10:36.385 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': False, 'limit': 100, 'accuracy': 0.54}
# 2024-02-06 13:10:36.911 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': False, 'limit': 50, 'accuracy': 0.56}
# 2024-02-06 13:10:37.442 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': False, 'limit': 20, 'accuracy': 0.6}
# 2024-02-06 13:10:37.974 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': False, 'limit': 10, 'accuracy': 0.5}
# 2024-02-06 13:10:38.592 | INFO     | __main__:<module>:68 - {'query_id': 1314, 'oversampling': 3.0, 'rescore': False, 'limit': 5, 'accuracy': 0.6}
# 100%|██████████| 100/100 [26:58<00:00, 16.19s/it]
